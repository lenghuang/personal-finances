# %% [markdown]
# # Personal Finance Analysis

# %%
# Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import glob
import hashlib

# %matplotlib inline

# %% [markdown]
# ## Reading in the Data
#
# Here, we expect some consistent format from the download button within Fidelity.
# In the event that we download more files for more up to date reflections on spending, I want to be able to easily add them and use the same code.
# Here, we read in multiple csv files and provide unique hashes to reference them again in the future if we need to.
#
# If we assume the average life of a human is 80 years x 365 days = 29,200 days, and we upper bound our spending by saying we have 100 transactions a day, we will have 2,920,000 transactions in a lifetime.
#
# `log_36(2920000) = 4.166`, so if we round up to a hash of 5, we should have more than enough numbers to track all of our spending.

# %%
def read_transaction_csv():
    # Get list of CSV files
    csv_files = glob.glob('../data/transactions_*.csv')

    # Read each file and add source column
    dfs = []
    for file in csv_files:
        df = pd.read_csv(file)
        df['SourceFile'] = file.split('/')[-1]  # Just the filename, not full path
        dfs.append(df)

    # Combine all DataFrames
    return pd.concat(dfs, ignore_index=True)

def create_row_hash(row):
    # Get column names to exclude
    exclude_cols = ['SourceFile']

    # Filter out excluded columns before hashing
    row_values = [str(row[col]) for col in row.index if col not in exclude_cols]
    row_str = ''.join(row_values)

    # Create hash
    full_hash = hashlib.sha256(row_str.encode()).hexdigest()
    return full_hash[:5]

def add_row_hash(df):
    # Apply to each row
    df['GroupingKey'] = df.apply(create_row_hash, axis=1)
    # Avoid duplicates with count as suffix
    df['RowHashID'] = df.groupby('GroupingKey').cumcount().add(1).astype(str).radd(df['GroupingKey'] + '_')
    df.set_index('RowHashID', inplace=True)
    return df

# Preview data
add_row_hash(read_transaction_csv())
# Out:
#                 Date                                        Description  \
# RowHashID
# e3637_1    6/11/2025     ALLY BANK DES TRANSFER INDN LEN G HUANG CO WEB
# 94c5e_1    6/11/2025            VENMO DES PAYMENT INDN LEN HUANG CO WEB
# 72b02_1    6/11/2025  ALLY BANK DES ID LEN G HUANG INDN LEN G HUANG ...
# 4871c_1    6/10/2025                             OZZIES FRESH MARKET NY
# a1c2b_1    6/10/2025                         SECURITY DEPOSIT UNION AVE
# ...              ...                                                ...
# 2d51e_1     1/2/2024      ONLINE BANKING TRANSFER FROM CHK CONFIRMATION
# 92d6d_1     1/1/2024                                 COURT SQUARE DINER
# ee82d_1     1/1/2024                                     NJT RAIL MYTIX
# f370a_1     1/1/2024                                             TARGET
# 7df83_1     1/1/2024                              ANNUAL MEMBERSHIP FEE
#
#                                     Institution  \
# RowHashID
# e3637_1    Bank of America - via Direct Web API
# 94c5e_1    Bank of America - via Direct Web API
# 72b02_1    Bank of America - via Direct Web API
# 4871c_1    Bank of America - via Direct Web API
# a1c2b_1           Venmo - via Direct Web Access
# ...                                         ...
# 2d51e_1    Bank of America - via Direct Web API
# 92d6d_1                                   Chase
# ee82d_1                                   Chase
# f370a_1                                   Chase
# 7df83_1                                   Chase
#
#                                                  Account            Category  \
# RowHashID
# e3637_1                          Adv Plus Banking - 2082           Transfers
# 94c5e_1                          Adv Plus Banking - 2082      Online Payment
# 72b02_1                          Adv Plus Banking - 2082              Income
# 4871c_1    Customized Cash Rewards Visa Signature - 0966           Groceries
# a1c2b_1                                            Venmo              Income
# ...                                                  ...                 ...
# 2d51e_1                          Adv Plus Banking - 2082           Transfers
# 92d6d_1                                   Other Spending  Restaurants/Dining
# ee82d_1                                   Other Spending    Public Transport
# f370a_1                                   Other Spending            Shopping
# 7df83_1                                      Travel Card      Fees & Charges
#
#           Is Hidden Is Pending    Amount                   SourceFile  \
# RowHashID
# e3637_1          No         No    ($400)  transactions_2025_06_13.csv
# 94c5e_1          No         No   ($2500)  transactions_2025_06_13.csv
# 72b02_1          No         No     $5000  transactions_2025_06_13.csv
# 4871c_1          No         No   ($6.99)  transactions_2025_06_13.csv
# a1c2b_1          No         No   ($2500)  transactions_2025_06_13.csv
# ...             ...        ...       ...                          ...
# 2d51e_1          No         No      $300  transactions_2025_06_13.csv
# 92d6d_1          No         No  ($77.65)  transactions_2025_06_13.csv
# ee82d_1          No         No    ($8.5)  transactions_2025_06_13.csv
# f370a_1          No         No  ($14.34)  transactions_2025_06_13.csv
# 7df83_1          No         No     ($95)  transactions_2025_06_13.csv
#
#           GroupingKey
# RowHashID
# e3637_1         e3637
# 94c5e_1         94c5e
# 72b02_1         72b02
# 4871c_1         4871c
# a1c2b_1         a1c2b
# ...               ...
# 2d51e_1         2d51e
# 92d6d_1         92d6d
# ee82d_1         ee82d
# f370a_1         f370a
# 7df83_1         7df83
#
# [1988 rows x 10 columns]

# %% [markdown]
# Now we can query for specific fields as such, in case we want to add logic overrides to specific rows.

# %%
def find_row_from_hash(hash='e3637'):
    df = add_row_hash(read_transaction_csv())
    return df[df.index.str.startswith(hash)]

find_row_from_hash()
# Out:
#                 Date                                     Description  \
# RowHashID
# e3637_1    6/11/2025  ALLY BANK DES TRANSFER INDN LEN G HUANG CO WEB
#
#                                     Institution                  Account  \
# RowHashID
# e3637_1    Bank of America - via Direct Web API  Adv Plus Banking - 2082
#
#             Category Is Hidden Is Pending  Amount  \
# RowHashID
# e3637_1    Transfers        No         No  ($400)
#
#                             SourceFile GroupingKey
# RowHashID
# e3637_1    transactions_2025_06_13.csv       e3637

# %% [markdown]
# # Dedupe the Data
#
# We'll also be able to detect duplicates across files potentially like this.

# %%
def find_duplicate_groups():
    df = add_row_hash(read_transaction_csv())
    return df[df.duplicated('GroupingKey', keep=False)]

find_duplicate_groups()
# Out:
#                 Date      Description  \
# RowHashID
# 4b67d_1    5/17/2025       PER PERSON
# 4b67d_2    5/17/2025       PER PERSON
# b7006_1    4/15/2025  OLD CHELSEA SNY
# b7006_2    4/15/2025  OLD CHELSEA SNY
# 7cb4f_1     4/1/2025  OLD CHELSEA SNY
# ...              ...              ...
# c685a_3    2/19/2024            LUNCH
# 9debd_1    1/21/2024         MOMOFUKU
# 9debd_2    1/21/2024         MOMOFUKU
# 5e2ce_1    1/13/2024             UBER
# 5e2ce_2    1/13/2024             UBER
#
#                                                Institution  \
# RowHashID
# 4b67d_1                      Venmo - via Direct Web Access
# 4b67d_2                      Venmo - via Direct Web Access
# b7006_1    Wells Fargo Online Banking - via Direct Web API
# b7006_2    Wells Fargo Online Banking - via Direct Web API
# 7cb4f_1    Wells Fargo Online Banking - via Direct Web API
# ...                                                    ...
# c685a_3                      Venmo - via Direct Web Access
# 9debd_1                      Venmo - via Direct Web Access
# 9debd_2                      Venmo - via Direct Web Access
# 5e2ce_1                      Venmo - via Direct Web Access
# 5e2ce_2                      Venmo - via Direct Web Access
#
#                                        Account            Category Is Hidden  \
# RowHashID
# 4b67d_1                                  Venmo              Income        No
# 4b67d_2                                  Venmo              Income        No
# b7006_1    BILT WORLD ELITE MASTERCARD ...7685  Restaurants/Dining        No
# b7006_2    BILT WORLD ELITE MASTERCARD ...7685  Restaurants/Dining        No
# 7cb4f_1    BILT WORLD ELITE MASTERCARD ...7685  Restaurants/Dining        No
# ...                                        ...                 ...       ...
# c685a_3                                  Venmo              Income        No
# 9debd_1                                  Venmo              Income        No
# 9debd_2                                  Venmo              Income        No
# 5e2ce_1                                  Venmo           Rideshare        No
# 5e2ce_2                                  Venmo           Rideshare        No
#
#           Is Pending    Amount                   SourceFile GroupingKey
# RowHashID
# 4b67d_1           No    $47.25  transactions_2025_06_13.csv       4b67d
# 4b67d_2           No    $47.25  transactions_2025_06_13.csv       4b67d
# b7006_1           No  ($93.01)  transactions_2025_06_13.csv       b7006
# b7006_2           No  ($93.01)  transactions_2025_06_13.csv       b7006
# 7cb4f_1           No   ($83.6)  transactions_2025_06_13.csv       7cb4f
# ...              ...       ...                          ...         ...
# c685a_3           No       $20  transactions_2025_06_13.csv       c685a
# 9debd_1           No    $24.49  transactions_2025_06_13.csv       9debd
# 9debd_2           No    $24.49  transactions_2025_06_13.csv       9debd
# 5e2ce_1           No    $15.47  transactions_2025_06_13.csv       5e2ce
# 5e2ce_2           No    $15.47  transactions_2025_06_13.csv       5e2ce
#
# [75 rows x 10 columns]

# %% [markdown]
# But it looks like these are actually not duplicates, they are venmo requests of the same kind to different people! Let's understand this more.

# %%
def duplicates_summary():
    # Read and process data
    df = add_row_hash(read_transaction_csv())

    # Group and aggregate
    grouped = df.groupby('GroupingKey').agg({
        'Description': 'first',
        'Date': ['min', 'max', 'count'],
        'Amount': 'first',
        'SourceFile': lambda x: ', '.join(set(x))  # Unique source files
    })

    # df.set_index('RowHashID', inplace=True)

    # Flatten multi-index columns
    grouped.columns = ['_'.join(col).strip() for col in grouped.columns.values]

    # Rename columns
    grouped.rename(columns={
        'GroupingKey_': 'GroupID',
        'Description_first': 'Description',
        'Date_count': 'DuplicateCount',
        'Date_min': 'FirstDate',
        'Date_max': 'LastDate',
        'Amount_first': 'Amount',
        'SourceFile_<lambda>': 'SourceFiles'
    }, inplace=True)

    # Filter for actual duplicates (count > 1)
    duplicates = grouped[grouped['DuplicateCount'] > 1]

    # Sort by most frequent duplicates first
    return duplicates.sort_values('DuplicateCount', ascending=False)

duplicates_summary()
# Out:
#                                                    Description   FirstDate  \
# GroupingKey
# fed3c                         MESSED UP SOME MATH WILL PENN PT   4/14/2024
# 839bd                                         WILL PENN TAVERN   4/14/2024
# 28855                                      RAJ S FRIDAY DINNER   4/21/2024
# c685a                                                    LUNCH   2/19/2024
# 9075a        BKOFAMERICA ATM WITHDRWL LAGUARDIA AIRPORT LAG...   1/21/2025
# 0d08b                                SHAVED ICE FRIDAY EVENING   4/21/2024
# 39ed8                                                ADDA SPOT  12/23/2024
# 9debd                                                 MOMOFUKU   1/21/2024
# f664c        BKOFAMERICA ATM WITHDRWL LONG ISLAND CITYJ LON...   6/20/2024
# ed8cb                                           HAPPY BIRTHDAY   7/21/2024
# e41d1                                          OLD CHELSEA SNY    2/1/2025
# e3826                                          OLD CHELSEA SNY    3/1/2025
# d6a9a                                    ELECTRICITY MAR APRIL    4/8/2024
# 17943                                    MALAY DINNER TIRAMISU   6/21/2024
# beb70                                                   DINNER    4/2/2024
# b7006                                          OLD CHELSEA SNY   4/15/2025
# b4e4a                   INTERNET TRANSFER FROM SAVINGS ACCOUNT    4/1/2025
# a7bd0                                           CMU DRAMA SHOW    5/2/2024
# a5268                                    AVANT GARD AVANTGARDN  11/10/2024
# 28cb6        SCUBA TONY DEPOSIT DOING THIS NOW SO I DON T F...   1/22/2025
# 4b67d                                               PER PERSON   5/17/2025
# 35b47                                      ELECTRICITY DEC JAN    1/9/2025
# 7cb4f                                          OLD CHELSEA SNY    4/1/2025
# 13172                                   GETYOURGUIDEOPERATIONS   2/26/2024
# 68cf0                                       PAYPAL CARNEGIE ME   12/3/2024
# 65993                                                   MASABI   5/11/2024
# 5e2ce                                                     UBER   1/13/2024
# 57963                                            GEORGIAN FOOD   3/25/2024
# 5694b                                       PAYPAL CARNEGIE ME   12/3/2024
# 504c0                                           NJT RAIL MYTIX   1/11/2025
# 4e5bf        INTERNET TRANSFER TO CERTIFICATE OF DEPOSIT AC...    4/1/2025
# 4d9d9                                                  DESSERT   2/25/2024
# 6fb25                                       TOO GOOD TO GO INC  10/19/2024
#
#                LastDate  DuplicateCount    Amount                  SourceFiles
# GroupingKey
# fed3c         4/14/2024               4     $1.46  transactions_2025_06_13.csv
# 839bd         4/14/2024               4       $26  transactions_2025_06_13.csv
# 28855         4/21/2024               4    $21.71  transactions_2025_06_13.csv
# c685a         2/19/2024               3       $20  transactions_2025_06_13.csv
# 9075a         1/21/2025               3    ($300)  transactions_2025_06_13.csv
# 0d08b         4/21/2024               3     $3.67  transactions_2025_06_13.csv
# 39ed8        12/23/2024               2    $61.62  transactions_2025_06_13.csv
# 9debd         1/21/2024               2    $24.49  transactions_2025_06_13.csv
# f664c         6/20/2024               2    ($100)  transactions_2025_06_13.csv
# ed8cb         7/21/2024               2        $5  transactions_2025_06_13.csv
# e41d1          2/1/2025               2   ($83.6)  transactions_2025_06_13.csv
# e3826          3/1/2025               2   ($83.6)  transactions_2025_06_13.csv
# d6a9a          4/8/2024               2    $66.91  transactions_2025_06_13.csv
# 17943         6/21/2024               2    $32.66  transactions_2025_06_13.csv
# beb70          4/2/2024               2    $26.25  transactions_2025_06_13.csv
# b7006         4/15/2025               2  ($93.01)  transactions_2025_06_13.csv
# b4e4a          4/1/2025               2     $7500  transactions_2025_06_13.csv
# a7bd0          5/2/2024               2    $31.72  transactions_2025_06_13.csv
# a5268        11/10/2024               2      ($6)  transactions_2025_06_13.csv
# 28cb6         1/22/2025               2       $75  transactions_2025_06_13.csv
# 4b67d         5/17/2025               2    $47.25  transactions_2025_06_13.csv
# 35b47          1/9/2025               2    $88.52  transactions_2025_06_13.csv
# 7cb4f          4/1/2025               2   ($83.6)  transactions_2025_06_13.csv
# 13172         2/26/2024               2   ($32.5)  transactions_2025_06_13.csv
# 68cf0         12/3/2024               2     ($10)  transactions_2025_06_13.csv
# 65993         5/11/2024               2   ($2.75)  transactions_2025_06_13.csv
# 5e2ce         1/13/2024               2    $15.47  transactions_2025_06_13.csv
# 57963         3/25/2024               2     $28.5  transactions_2025_06_13.csv
# 5694b         12/3/2024               2     ($10)  transactions_2025_06_13.csv
# 504c0         1/11/2025               2    ($8.9)  transactions_2025_06_13.csv
# 4e5bf          4/1/2025               2   ($7500)  transactions_2025_06_13.csv
# 4d9d9         2/25/2024               2      $5.8  transactions_2025_06_13.csv
# 6fb25        10/19/2024               2   ($4.99)  transactions_2025_06_13.csv

# %%
def find_duplicate_groups():
    # Read and process data
    df = add_row_hash(read_transaction_csv())

    # Group and aggregate
    grouped = df.groupby('GroupingKey').agg({
        'Description': 'first',
        'Date': ['min', 'max', 'count'],
        'Amount': 'first',
        'SourceFile': lambda x: ', '.join(set(x))  # Unique source files
    })

    # df.set_index('RowHashID', inplace=True)

    # Flatten multi-index columns
    grouped.columns = ['_'.join(col).strip() for col in grouped.columns.values]

    # Rename columns
    grouped.rename(columns={
        'GroupingKey_': 'GroupID',
        'Description_first': 'Description',
        'Date_count': 'DuplicateCount',
        'Date_min': 'FirstDate',
        'Date_max': 'LastDate',
        'Amount_first': 'Amount',
        'SourceFile_<lambda>': 'SourceFiles'
    }, inplace=True)

    # Filter for actual duplicates (count > 1)
    duplicates = grouped[grouped['DuplicateCount'] > 1]

    # Sort by most frequent duplicates first
    return duplicates.sort_values('DuplicateCount', ascending=False)

find_duplicate_groups()
# Out:
#                                                    Description   FirstDate  \
# GroupingKey
# fed3c                         MESSED UP SOME MATH WILL PENN PT   4/14/2024
# 839bd                                         WILL PENN TAVERN   4/14/2024
# 28855                                      RAJ S FRIDAY DINNER   4/21/2024
# c685a                                                    LUNCH   2/19/2024
# 9075a        BKOFAMERICA ATM WITHDRWL LAGUARDIA AIRPORT LAG...   1/21/2025
# 0d08b                                SHAVED ICE FRIDAY EVENING   4/21/2024
# 39ed8                                                ADDA SPOT  12/23/2024
# 9debd                                                 MOMOFUKU   1/21/2024
# f664c        BKOFAMERICA ATM WITHDRWL LONG ISLAND CITYJ LON...   6/20/2024
# ed8cb                                           HAPPY BIRTHDAY   7/21/2024
# e41d1                                          OLD CHELSEA SNY    2/1/2025
# e3826                                          OLD CHELSEA SNY    3/1/2025
# d6a9a                                    ELECTRICITY MAR APRIL    4/8/2024
# 17943                                    MALAY DINNER TIRAMISU   6/21/2024
# beb70                                                   DINNER    4/2/2024
# b7006                                          OLD CHELSEA SNY   4/15/2025
# b4e4a                   INTERNET TRANSFER FROM SAVINGS ACCOUNT    4/1/2025
# a7bd0                                           CMU DRAMA SHOW    5/2/2024
# a5268                                    AVANT GARD AVANTGARDN  11/10/2024
# 28cb6        SCUBA TONY DEPOSIT DOING THIS NOW SO I DON T F...   1/22/2025
# 4b67d                                               PER PERSON   5/17/2025
# 35b47                                      ELECTRICITY DEC JAN    1/9/2025
# 7cb4f                                          OLD CHELSEA SNY    4/1/2025
# 13172                                   GETYOURGUIDEOPERATIONS   2/26/2024
# 68cf0                                       PAYPAL CARNEGIE ME   12/3/2024
# 65993                                                   MASABI   5/11/2024
# 5e2ce                                                     UBER   1/13/2024
# 57963                                            GEORGIAN FOOD   3/25/2024
# 5694b                                       PAYPAL CARNEGIE ME   12/3/2024
# 504c0                                           NJT RAIL MYTIX   1/11/2025
# 4e5bf        INTERNET TRANSFER TO CERTIFICATE OF DEPOSIT AC...    4/1/2025
# 4d9d9                                                  DESSERT   2/25/2024
# 6fb25                                       TOO GOOD TO GO INC  10/19/2024
#
#                LastDate  DuplicateCount    Amount                  SourceFiles
# GroupingKey
# fed3c         4/14/2024               4     $1.46  transactions_2025_06_13.csv
# 839bd         4/14/2024               4       $26  transactions_2025_06_13.csv
# 28855         4/21/2024               4    $21.71  transactions_2025_06_13.csv
# c685a         2/19/2024               3       $20  transactions_2025_06_13.csv
# 9075a         1/21/2025               3    ($300)  transactions_2025_06_13.csv
# 0d08b         4/21/2024               3     $3.67  transactions_2025_06_13.csv
# 39ed8        12/23/2024               2    $61.62  transactions_2025_06_13.csv
# 9debd         1/21/2024               2    $24.49  transactions_2025_06_13.csv
# f664c         6/20/2024               2    ($100)  transactions_2025_06_13.csv
# ed8cb         7/21/2024               2        $5  transactions_2025_06_13.csv
# e41d1          2/1/2025               2   ($83.6)  transactions_2025_06_13.csv
# e3826          3/1/2025               2   ($83.6)  transactions_2025_06_13.csv
# d6a9a          4/8/2024               2    $66.91  transactions_2025_06_13.csv
# 17943         6/21/2024               2    $32.66  transactions_2025_06_13.csv
# beb70          4/2/2024               2    $26.25  transactions_2025_06_13.csv
# b7006         4/15/2025               2  ($93.01)  transactions_2025_06_13.csv
# b4e4a          4/1/2025               2     $7500  transactions_2025_06_13.csv
# a7bd0          5/2/2024               2    $31.72  transactions_2025_06_13.csv
# a5268        11/10/2024               2      ($6)  transactions_2025_06_13.csv
# 28cb6         1/22/2025               2       $75  transactions_2025_06_13.csv
# 4b67d         5/17/2025               2    $47.25  transactions_2025_06_13.csv
# 35b47          1/9/2025               2    $88.52  transactions_2025_06_13.csv
# 7cb4f          4/1/2025               2   ($83.6)  transactions_2025_06_13.csv
# 13172         2/26/2024               2   ($32.5)  transactions_2025_06_13.csv
# 68cf0         12/3/2024               2     ($10)  transactions_2025_06_13.csv
# 65993         5/11/2024               2   ($2.75)  transactions_2025_06_13.csv
# 5e2ce         1/13/2024               2    $15.47  transactions_2025_06_13.csv
# 57963         3/25/2024               2     $28.5  transactions_2025_06_13.csv
# 5694b         12/3/2024               2     ($10)  transactions_2025_06_13.csv
# 504c0         1/11/2025               2    ($8.9)  transactions_2025_06_13.csv
# 4e5bf          4/1/2025               2   ($7500)  transactions_2025_06_13.csv
# 4d9d9         2/25/2024               2      $5.8  transactions_2025_06_13.csv
# 6fb25        10/19/2024               2   ($4.99)  transactions_2025_06_13.csv

# %% [markdown]
# How might we solve duplicate within a file though? Many of these are Venmo statements that some of the naming/description gets cut out from the description. Namely, should we add better descriptions before passing in the data?

# %% [markdown]
# ## Reformatting the Data
#
# Here, we want to convert some of the values to things that will be easier to work with.
# When reading it in, everything is a string. We want:
# - the string `Date` to be datetime objects
# - `Is Hidden` / `Is Pending` to bools
# - `Amount` to be positive/negative numbers rather than accounting style strings.

# %%
def convert_types(df):
    df['Date'] = pd.to_datetime(df['Date'])
    df['Is Hidden'] = df['Is Hidden'].replace({'yes': True, 'no': False})
    df['Is Pending'] = df['Is Pending'].replace({'yes': True, 'no': False})

    return df

convert_types(add_row_hash(read_transaction_csv()))
# Out:
#                 Date                                        Description  \
# RowHashID
# e3637_1   2025-06-11     ALLY BANK DES TRANSFER INDN LEN G HUANG CO WEB
# 94c5e_1   2025-06-11            VENMO DES PAYMENT INDN LEN HUANG CO WEB
# 72b02_1   2025-06-11  ALLY BANK DES ID LEN G HUANG INDN LEN G HUANG ...
# 4871c_1   2025-06-10                             OZZIES FRESH MARKET NY
# a1c2b_1   2025-06-10                         SECURITY DEPOSIT UNION AVE
# ...              ...                                                ...
# 2d51e_1   2024-01-02      ONLINE BANKING TRANSFER FROM CHK CONFIRMATION
# 92d6d_1   2024-01-01                                 COURT SQUARE DINER
# ee82d_1   2024-01-01                                     NJT RAIL MYTIX
# f370a_1   2024-01-01                                             TARGET
# 7df83_1   2024-01-01                              ANNUAL MEMBERSHIP FEE
#
#                                     Institution  \
# RowHashID
# e3637_1    Bank of America - via Direct Web API
# 94c5e_1    Bank of America - via Direct Web API
# 72b02_1    Bank of America - via Direct Web API
# 4871c_1    Bank of America - via Direct Web API
# a1c2b_1           Venmo - via Direct Web Access
# ...                                         ...
# 2d51e_1    Bank of America - via Direct Web API
# 92d6d_1                                   Chase
# ee82d_1                                   Chase
# f370a_1                                   Chase
# 7df83_1                                   Chase
#
#                                                  Account            Category  \
# RowHashID
# e3637_1                          Adv Plus Banking - 2082           Transfers
# 94c5e_1                          Adv Plus Banking - 2082      Online Payment
# 72b02_1                          Adv Plus Banking - 2082              Income
# 4871c_1    Customized Cash Rewards Visa Signature - 0966           Groceries
# a1c2b_1                                            Venmo              Income
# ...                                                  ...                 ...
# 2d51e_1                          Adv Plus Banking - 2082           Transfers
# 92d6d_1                                   Other Spending  Restaurants/Dining
# ee82d_1                                   Other Spending    Public Transport
# f370a_1                                   Other Spending            Shopping
# 7df83_1                                      Travel Card      Fees & Charges
#
#           Is Hidden Is Pending    Amount                   SourceFile  \
# RowHashID
# e3637_1          No         No    ($400)  transactions_2025_06_13.csv
# 94c5e_1          No         No   ($2500)  transactions_2025_06_13.csv
# 72b02_1          No         No     $5000  transactions_2025_06_13.csv
# 4871c_1          No         No   ($6.99)  transactions_2025_06_13.csv
# a1c2b_1          No         No   ($2500)  transactions_2025_06_13.csv
# ...             ...        ...       ...                          ...
# 2d51e_1          No         No      $300  transactions_2025_06_13.csv
# 92d6d_1          No         No  ($77.65)  transactions_2025_06_13.csv
# ee82d_1          No         No    ($8.5)  transactions_2025_06_13.csv
# f370a_1          No         No  ($14.34)  transactions_2025_06_13.csv
# 7df83_1          No         No     ($95)  transactions_2025_06_13.csv
#
#           GroupingKey
# RowHashID
# e3637_1         e3637
# 94c5e_1         94c5e
# 72b02_1         72b02
# 4871c_1         4871c
# a1c2b_1         a1c2b
# ...               ...
# 2d51e_1         2d51e
# 92d6d_1         92d6d
# ee82d_1         ee82d
# f370a_1         f370a
# 7df83_1         7df83
#
# [1988 rows x 10 columns]
