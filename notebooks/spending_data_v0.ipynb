# %% [markdown]
# # Personal Finance Analysis

# %%
# Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import glob
import hashlib

# %matplotlib inline

# %% [markdown]
# ## Reading in the Data
#
# Here, we expect some consistent format from the download button within Fidelity.
# In the event that we download more files for more up to date reflections on spending, I want to be able to easily add them and use the same code.
# Here, we read in multiple csv files and provide unique hashes to reference them again in the future if we need to.
#
# If we assume the average life of a human is 80 years x 365 days = 29,200 days, and we upper bound our spending by saying we have 100 transactions a day, we will have 2,920,000 transactions in a lifetime.
#
# `log_36(2920000) = 4.166`, so if we round up to a hash of 5, we should have more than enough numbers to track all of our spending.

# %%
def read_transaction_csv():
    # Get list of CSV files
    csv_files = glob.glob('../data/transactions_*.csv')

    # Read each file and add source column
    dfs = []
    for file in csv_files:
        df = pd.read_csv(file)
        df['SourceFile'] = file.split('/')[-1]  # Just the filename, not full path
        dfs.append(df)

    # Combine all DataFrames
    return pd.concat(dfs, ignore_index=True)

def create_row_hash(row):
    # Get column names to exclude
    exclude_cols = ['SourceFile']

    # Filter out excluded columns before hashing
    row_values = [str(row[col]) for col in row.index if col not in exclude_cols]
    row_str = ''.join(row_values)

    # Create hash
    full_hash = hashlib.sha256(row_str.encode()).hexdigest()
    return full_hash[:5]

def add_row_hash(df):
    # Apply to each row
    df['RowHashID'] = df.apply(create_row_hash, axis=1)
    # Avoid duplicates with count as suffix
    df['RowHashID'] = df.groupby('RowHashID').cumcount().add(1).astype(str).radd(df['RowHashID'] + '_')
    df.set_index('RowHashID', inplace=True)
    return df

# Preview data
add_row_hash(read_transaction_csv())
# Out:
#                 Date                                        Description  \
# RowHashID
# e3637_1    6/11/2025     ALLY BANK DES TRANSFER INDN LEN G HUANG CO WEB
# 94c5e_1    6/11/2025            VENMO DES PAYMENT INDN LEN HUANG CO WEB
# 72b02_1    6/11/2025  ALLY BANK DES ID LEN G HUANG INDN LEN G HUANG ...
# 4871c_1    6/10/2025                             OZZIES FRESH MARKET NY
# a1c2b_1    6/10/2025                         SECURITY DEPOSIT UNION AVE
# ...              ...                                                ...
# 2d51e_1     1/2/2024      ONLINE BANKING TRANSFER FROM CHK CONFIRMATION
# 92d6d_1     1/1/2024                                 COURT SQUARE DINER
# ee82d_1     1/1/2024                                     NJT RAIL MYTIX
# f370a_1     1/1/2024                                             TARGET
# 7df83_1     1/1/2024                              ANNUAL MEMBERSHIP FEE
#
#                                     Institution  \
# RowHashID
# e3637_1    Bank of America - via Direct Web API
# 94c5e_1    Bank of America - via Direct Web API
# 72b02_1    Bank of America - via Direct Web API
# 4871c_1    Bank of America - via Direct Web API
# a1c2b_1           Venmo - via Direct Web Access
# ...                                         ...
# 2d51e_1    Bank of America - via Direct Web API
# 92d6d_1                                   Chase
# ee82d_1                                   Chase
# f370a_1                                   Chase
# 7df83_1                                   Chase
#
#                                                  Account            Category  \
# RowHashID
# e3637_1                          Adv Plus Banking - 2082           Transfers
# 94c5e_1                          Adv Plus Banking - 2082      Online Payment
# 72b02_1                          Adv Plus Banking - 2082              Income
# 4871c_1    Customized Cash Rewards Visa Signature - 0966           Groceries
# a1c2b_1                                            Venmo              Income
# ...                                                  ...                 ...
# 2d51e_1                          Adv Plus Banking - 2082           Transfers
# 92d6d_1                                   Other Spending  Restaurants/Dining
# ee82d_1                                   Other Spending    Public Transport
# f370a_1                                   Other Spending            Shopping
# 7df83_1                                      Travel Card      Fees & Charges
#
#           Is Hidden Is Pending    Amount                   SourceFile
# RowHashID
# e3637_1          No         No    ($400)  transactions_2025_06_13.csv
# 94c5e_1          No         No   ($2500)  transactions_2025_06_13.csv
# 72b02_1          No         No     $5000  transactions_2025_06_13.csv
# 4871c_1          No         No   ($6.99)  transactions_2025_06_13.csv
# a1c2b_1          No         No   ($2500)  transactions_2025_06_13.csv
# ...             ...        ...       ...                          ...
# 2d51e_1          No         No      $300  transactions_2025_06_13.csv
# 92d6d_1          No         No  ($77.65)  transactions_2025_06_13.csv
# ee82d_1          No         No    ($8.5)  transactions_2025_06_13.csv
# f370a_1          No         No  ($14.34)  transactions_2025_06_13.csv
# 7df83_1          No         No     ($95)  transactions_2025_06_13.csv
#
# [1988 rows x 9 columns]

# %% [markdown]
# Now we can query for specific fields as such, in case we want to add logic overrides to specific rows.

# %%
def find_row_from_hash(hash='e3637'):
    df = add_row_hash(read_transaction_csv())
    return df[df.index.str.startswith(hash)]

find_row_from_hash()
# Out:
#                 Date                                     Description  \
# RowHashID
# e3637_1    6/11/2025  ALLY BANK DES TRANSFER INDN LEN G HUANG CO WEB
#
#                                     Institution                  Account  \
# RowHashID
# e3637_1    Bank of America - via Direct Web API  Adv Plus Banking - 2082
#
#             Category Is Hidden Is Pending  Amount                   SourceFile
# RowHashID
# e3637_1    Transfers        No         No  ($400)  transactions_2025_06_13.csv

# %% [markdown]
# # Dedupe the Data
#
# We'll also be able to detect duplicates across files potentially like this.

# %%
def find_duplicate_groups():
    df = add_row_hash(read_transaction_csv())

    # Extract base hash and create group IDs
    df['BaseHash'] = df.index.str.replace(r'_\d+$', '', regex=True)
    duplicates = df[df.duplicated('BaseHash', keep=False)]

    return duplicates

find_duplicate_groups()
# Out:
#                 Date      Description  \
# RowHashID
# 4b67d_1    5/17/2025       PER PERSON
# 4b67d_2    5/17/2025       PER PERSON
# b7006_1    4/15/2025  OLD CHELSEA SNY
# b7006_2    4/15/2025  OLD CHELSEA SNY
# 7cb4f_1     4/1/2025  OLD CHELSEA SNY
# ...              ...              ...
# c685a_3    2/19/2024            LUNCH
# 9debd_1    1/21/2024         MOMOFUKU
# 9debd_2    1/21/2024         MOMOFUKU
# 5e2ce_1    1/13/2024             UBER
# 5e2ce_2    1/13/2024             UBER
#
#                                                Institution  \
# RowHashID
# 4b67d_1                      Venmo - via Direct Web Access
# 4b67d_2                      Venmo - via Direct Web Access
# b7006_1    Wells Fargo Online Banking - via Direct Web API
# b7006_2    Wells Fargo Online Banking - via Direct Web API
# 7cb4f_1    Wells Fargo Online Banking - via Direct Web API
# ...                                                    ...
# c685a_3                      Venmo - via Direct Web Access
# 9debd_1                      Venmo - via Direct Web Access
# 9debd_2                      Venmo - via Direct Web Access
# 5e2ce_1                      Venmo - via Direct Web Access
# 5e2ce_2                      Venmo - via Direct Web Access
#
#                                        Account            Category Is Hidden  \
# RowHashID
# 4b67d_1                                  Venmo              Income        No
# 4b67d_2                                  Venmo              Income        No
# b7006_1    BILT WORLD ELITE MASTERCARD ...7685  Restaurants/Dining        No
# b7006_2    BILT WORLD ELITE MASTERCARD ...7685  Restaurants/Dining        No
# 7cb4f_1    BILT WORLD ELITE MASTERCARD ...7685  Restaurants/Dining        No
# ...                                        ...                 ...       ...
# c685a_3                                  Venmo              Income        No
# 9debd_1                                  Venmo              Income        No
# 9debd_2                                  Venmo              Income        No
# 5e2ce_1                                  Venmo           Rideshare        No
# 5e2ce_2                                  Venmo           Rideshare        No
#
#           Is Pending    Amount                   SourceFile BaseHash
# RowHashID
# 4b67d_1           No    $47.25  transactions_2025_06_13.csv    4b67d
# 4b67d_2           No    $47.25  transactions_2025_06_13.csv    4b67d
# b7006_1           No  ($93.01)  transactions_2025_06_13.csv    b7006
# b7006_2           No  ($93.01)  transactions_2025_06_13.csv    b7006
# 7cb4f_1           No   ($83.6)  transactions_2025_06_13.csv    7cb4f
# ...              ...       ...                          ...      ...
# c685a_3           No       $20  transactions_2025_06_13.csv    c685a
# 9debd_1           No    $24.49  transactions_2025_06_13.csv    9debd
# 9debd_2           No    $24.49  transactions_2025_06_13.csv    9debd
# 5e2ce_1           No    $15.47  transactions_2025_06_13.csv    5e2ce
# 5e2ce_2           No    $15.47  transactions_2025_06_13.csv    5e2ce
#
# [75 rows x 10 columns]

# %% [markdown]
# How might we solve duplicate within a file though? Many of these are Venmo statements that some of the naming/description gets cut out from the description. Namely, should we add better descriptions before passing in the data?

# %% [markdown]
# ## Reformatting the Data
#
# Here, we want to convert some of the values to things that will be easier to work with.
# When reading it in, everything is a string. We want:
# - the string `Date` to be datetime objects
# - `Is Hidden` / `Is Pending` to bools
# - `Amount` to be positive/negative numbers rather than accounting style strings.

# %%
def convert_types(df):
    df['Date'] = pd.to_datetime(df['Date'])
    df['Is Hidden'] = df['Is Hidden'].replace({'yes': True, 'no': False})
    df['Is Pending'] = df['Is Pending'].replace({'yes': True, 'no': False})

    return df

convert_types(add_row_hash(read_transaction_csv()))
# Out:
#                                                          Date  \
# RowHashID
# f35f80a5580758314f7e81c403c96f3a88372409022f7cc... 2025-06-11
# 97ae98dce283d0803bf021ccfc33a5cac5c9f55e09486c7... 2025-06-11
# 1befc714d8fdd198dbf448d5a5fc60f65290a9a9f266cce... 2025-06-11
# d59059c9936f5432f346f30a1e7eb1fb2d54bae871f11a9... 2025-06-10
# 33bf93e9bcc20a6ee5927cbf6874ebd2fa744854e653862... 2025-06-10
# ...                                                       ...
# 03c76a846b3e17045fbea5b5d044af3b3879c481a9b0666... 2024-01-02
# 741065bc7f441776aa1f35cea1566943f0f43f89ed53ebf... 2024-01-01
# 4681d08e3149d82f0883d0358d6b189f3f2df6aab0f6141... 2024-01-01
# bda7d3eb104c4f57cdaf40fb59dc3e06dcdc984f8b9276f... 2024-01-01
# 61f68b508b9da8274686258d01b63afae2eb5ba24253673... 2024-01-01
#
#                                                                                           Description  \
# RowHashID
# f35f80a5580758314f7e81c403c96f3a88372409022f7cc...     ALLY BANK DES TRANSFER INDN LEN G HUANG CO WEB
# 97ae98dce283d0803bf021ccfc33a5cac5c9f55e09486c7...            VENMO DES PAYMENT INDN LEN HUANG CO WEB
# 1befc714d8fdd198dbf448d5a5fc60f65290a9a9f266cce...  ALLY BANK DES ID LEN G HUANG INDN LEN G HUANG ...
