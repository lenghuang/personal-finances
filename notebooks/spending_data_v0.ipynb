# %% [markdown]
# # Personal Finance Analysis

# %%
# Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import glob
import hashlib

# %matplotlib inline

# %% [markdown]
# ## Reading in the Data
#
# Here, we expect some consistent format from the download button within Fidelity.
# In the event that we download more files for more up to date reflections on spending, I want to be able to easily add them and use the same code.
# Here, we read in multiple csv files and provide unique hashes to reference them again in the future if we need to.
#
# If we assume the average life of a human is 80 years x 365 days = 29,200 days, and we upper bound our spending by saying we have 100 transactions a day, we will have 2,920,000 transactions in a lifetime.
#
# `log_36(2920000) = 4.166`, so if we round up to a hash of 5, we should have more than enough numbers to track all of our spending.

# %%
def read_transaction_csv():
    # Get list of CSV files
    csv_files = glob.glob('../data/transactions_*.csv')

    # If no files found, return empty DataFrame
    if not csv_files:
        return pd.DataFrame()

    # Read each file and add source column
    dfs = []
    for file in csv_files:
        try:
            df = pd.read_csv(file)
            df['SourceFile'] = file.split('/')[-1]  # Just the filename, not full path
            dfs.append(df)
        except Exception as e:
            print(f"Error reading {file}: {str(e)}")

    # Combine all DataFrames
    if not dfs:
        return pd.DataFrame()

    return pd.concat(dfs, ignore_index=True)

def create_row_hashes(row):
    # Get column names to exclude
    exclude_cols = ['SourceFile']

    # Get row values for both intra and inter file hashes
    row_values_intra = [str(row[col]) for col in row.index if col not in exclude_cols]
    row_values_inter = [str(row[col]) for col in row.index]

    # Create hash strings
    row_str_intra = ''.join(row_values_intra)
    row_str_inter = ''.join(row_values_inter)

    # Create hashes
    intra_hash = hashlib.sha256(row_str_intra.encode()).hexdigest()
    inter_hash = hashlib.sha256(row_str_inter.encode()).hexdigest()

    return pd.Series([intra_hash[:5], inter_hash[:5]])

def add_row_hashes(df):
    if df.empty:
        return df

    # Apply to each row and get both hash values
    df[['IntraGroupingKey', 'InterGroupingKey']] = df.apply(create_row_hashes, axis=1)

    # Avoid duplicates with count as suffix
    df['IntraRowHashID'] = df.groupby('IntraGroupingKey').cumcount().add(1).astype(str).radd(df['IntraGroupingKey'] + '_')
    df['InterRowHashID'] = df.groupby('InterGroupingKey').cumcount().add(1).astype(str).radd(df['InterGroupingKey'] + '_')

    df.set_index('InterRowHashID', inplace=True)
    return df

# Preview data
add_row_hashes(read_transaction_csv())
# Out:
#                      Date                                        Description  \
# InterRowHashID
# 4d236_1         6/11/2025     ALLY BANK DES TRANSFER INDN LEN G HUANG CO WEB
# 381b5_1         6/11/2025            VENMO DES PAYMENT INDN LEN HUANG CO WEB
# 8e2b1_1         6/11/2025  ALLY BANK DES ID LEN G HUANG INDN LEN G HUANG ...
# 5e116_1         6/10/2025                             OZZIES FRESH MARKET NY
# 30ac5_1         6/10/2025                         SECURITY DEPOSIT UNION AVE
# ...                   ...                                                ...
# a7b69_1          1/2/2024      ONLINE BANKING TRANSFER FROM CHK CONFIRMATION
# 05463_1          1/1/2024                                 COURT SQUARE DINER
# 2cf10_1          1/1/2024                                     NJT RAIL MYTIX
# ff421_1          1/1/2024                                             TARGET
# 01228_1          1/1/2024                              ANNUAL MEMBERSHIP FEE
#
#                                          Institution  \
# InterRowHashID
# 4d236_1         Bank of America - via Direct Web API
# 381b5_1         Bank of America - via Direct Web API
# 8e2b1_1         Bank of America - via Direct Web API
# 5e116_1         Bank of America - via Direct Web API
# 30ac5_1                Venmo - via Direct Web Access
# ...                                              ...
# a7b69_1         Bank of America - via Direct Web API
# 05463_1                                        Chase
# 2cf10_1                                        Chase
# ff421_1                                        Chase
# 01228_1                                        Chase
#
#                                                       Account  \
# InterRowHashID
# 4d236_1                               Adv Plus Banking - 2082
# 381b5_1                               Adv Plus Banking - 2082
# 8e2b1_1                               Adv Plus Banking - 2082
# 5e116_1         Customized Cash Rewards Visa Signature - 0966
# 30ac5_1                                                 Venmo
# ...                                                       ...
# a7b69_1                               Adv Plus Banking - 2082
# 05463_1                                        Other Spending
# 2cf10_1                                        Other Spending
# ff421_1                                        Other Spending
# 01228_1                                           Travel Card
#
#                           Category Is Hidden Is Pending    Amount  \
# InterRowHashID
# 4d236_1                  Transfers        No         No    ($400)
# 381b5_1             Online Payment        No         No   ($2500)
# 8e2b1_1                     Income        No         No     $5000
# 5e116_1                  Groceries        No         No   ($6.99)
# 30ac5_1                     Income        No         No   ($2500)
# ...                            ...       ...        ...       ...
# a7b69_1                  Transfers        No         No      $300
# 05463_1         Restaurants/Dining        No         No  ($77.65)
# 2cf10_1           Public Transport        No         No    ($8.5)
# ff421_1                   Shopping        No         No  ($14.34)
# 01228_1             Fees & Charges        No         No     ($95)
#
#                                                SourceFile IntraGroupingKey  \
# InterRowHashID
# 4d236_1         transactions_dummy_to_test_duplicates.csv            e3637
# 381b5_1         transactions_dummy_to_test_duplicates.csv            94c5e
# 8e2b1_1         transactions_dummy_to_test_duplicates.csv            72b02
# 5e116_1         transactions_dummy_to_test_duplicates.csv            4871c
# 30ac5_1         transactions_dummy_to_test_duplicates.csv            a1c2b
# ...                                                   ...              ...
# a7b69_1                       transactions_2025_06_13.csv            2d51e
# 05463_1                       transactions_2025_06_13.csv            92d6d
# 2cf10_1                       transactions_2025_06_13.csv            ee82d
# ff421_1                       transactions_2025_06_13.csv            f370a
# 01228_1                       transactions_2025_06_13.csv            7df83
#
#                InterGroupingKey IntraRowHashID
# InterRowHashID
# 4d236_1                   4d236        e3637_1
# 381b5_1                   381b5        94c5e_1
# 8e2b1_1                   8e2b1        72b02_1
# 5e116_1                   5e116        4871c_1
# 30ac5_1                   30ac5        a1c2b_1
# ...                         ...            ...
# a7b69_1                   a7b69        2d51e_2
# 05463_1                   05463        92d6d_2
# 2cf10_1                   2cf10        ee82d_2
# ff421_1                   ff421        f370a_2
# 01228_1                   01228        7df83_2
#
# [3976 rows x 12 columns]

# %% [markdown]
# Now we can query for specific fields as such, in case we want to add logic overrides to specific rows.

# %%
# def find_row_from_hash(df, hash='f35f8'):
#     return df[df.index.str.startswith(hash)]

def find_row_from_hash(df, hash='f35f8'):
    idx_str = df.index.astype(str)
    hits = df[idx_str.str.startswith(str(hash))]

    if hits.empty:
        print(f"No rows match prefix {hash!r}")
    return hits

find_row_from_hash(add_row_hashes(read_transaction_csv()))
# Out:
#                      Date                                     Description  \
# InterRowHashID
# f35f8_1         6/11/2025  ALLY BANK DES TRANSFER INDN LEN G HUANG CO WEB
#
#                                          Institution                  Account  \
# InterRowHashID
# f35f8_1         Bank of America - via Direct Web API  Adv Plus Banking - 2082
#
#                  Category Is Hidden Is Pending  Amount  \
# InterRowHashID
# f35f8_1         Transfers        No         No  ($400)
#
#                                  SourceFile IntraGroupingKey InterGroupingKey  \
# InterRowHashID
# f35f8_1         transactions_2025_06_13.csv            e3637            f35f8
#
#                IntraRowHashID
# InterRowHashID
# f35f8_1               e3637_2

# %% [markdown]
# # Dedupe the Data
#
# We'll also be able to detect duplicates across files potentially like this. Specifically, we'll look for duplicates WITHIN files.
#
# The `IntraGroupingkey` tells us about duplicates within a file (bank integration errors) and the `InterGroupingKey` tells us about duplicates across files (downloading csv errors).

# %%
def find_duplicate_groups():
    df = add_row_hashes(read_transaction_csv())
    return df[df.duplicated('IntraGroupingKey', keep=False)]

find_duplicate_groups().head()
# Out:
#                      Date                                        Description  \
# InterRowHashID
# 4d236_1         6/11/2025     ALLY BANK DES TRANSFER INDN LEN G HUANG CO WEB
# 381b5_1         6/11/2025            VENMO DES PAYMENT INDN LEN HUANG CO WEB
# 8e2b1_1         6/11/2025  ALLY BANK DES ID LEN G HUANG INDN LEN G HUANG ...
# 5e116_1         6/10/2025                             OZZIES FRESH MARKET NY
# 30ac5_1         6/10/2025                         SECURITY DEPOSIT UNION AVE
#
#                                          Institution  \
# InterRowHashID
# 4d236_1         Bank of America - via Direct Web API
# 381b5_1         Bank of America - via Direct Web API
# 8e2b1_1         Bank of America - via Direct Web API
# 5e116_1         Bank of America - via Direct Web API
# 30ac5_1                Venmo - via Direct Web Access
#
#                                                       Account        Category  \
# InterRowHashID
# 4d236_1                               Adv Plus Banking - 2082       Transfers
# 381b5_1                               Adv Plus Banking - 2082  Online Payment
# 8e2b1_1                               Adv Plus Banking - 2082          Income
# 5e116_1         Customized Cash Rewards Visa Signature - 0966       Groceries
# 30ac5_1                                                 Venmo          Income
#
#                Is Hidden Is Pending   Amount  \
# InterRowHashID
# 4d236_1               No         No   ($400)
# 381b5_1               No         No  ($2500)
# 8e2b1_1               No         No    $5000
# 5e116_1               No         No  ($6.99)
# 30ac5_1               No         No  ($2500)
#
#                                                SourceFile IntraGroupingKey  \
# InterRowHashID
# 4d236_1         transactions_dummy_to_test_duplicates.csv            e3637
# 381b5_1         transactions_dummy_to_test_duplicates.csv            94c5e
# 8e2b1_1         transactions_dummy_to_test_duplicates.csv            72b02
# 5e116_1         transactions_dummy_to_test_duplicates.csv            4871c
# 30ac5_1         transactions_dummy_to_test_duplicates.csv            a1c2b
#
#                InterGroupingKey IntraRowHashID
# InterRowHashID
# 4d236_1                   4d236        e3637_1
# 381b5_1                   381b5        94c5e_1
# 8e2b1_1                   8e2b1        72b02_1
# 5e116_1                   5e116        4871c_1
# 30ac5_1                   30ac5        a1c2b_1

# %% [markdown]
# But it looks like these are actually not duplicates, they are venmo requests of the same kind to different people! Let's understand this more.

# %%
def duplicates_summary(df, key='IntraGroupingKey'):
    # Group and aggregate
    grouped = df.groupby(key).agg({
        'Description': 'first',
        'Date': ['min', 'max', 'count'],
        'Amount': 'first',
        'SourceFile': lambda x: ', '.join(set(x))  # Unique source files
    })

    # df.set_index('RowHashID', inplace=True)

    # Flatten multi-index columns
    grouped.columns = ['_'.join(col).strip() for col in grouped.columns.values]

    # Rename columns
    grouped.rename(columns={
        'GroupingKey_': 'GroupID',
        'Description_first': 'Description',
        'Date_count': 'DuplicateCount',
        'Date_min': 'FirstDate',
        'Date_max': 'LastDate',
        'Amount_first': 'Amount',
        'SourceFile_<lambda>': 'SourceFiles'
    }, inplace=True)

    # Filter for actual duplicates (count > 1)
    duplicates = grouped[grouped['DuplicateCount'] > 1]

    # Sort by most frequent duplicates first
    return duplicates.sort_values('DuplicateCount', ascending=False)

duplicates_summary(add_row_hashes(read_transaction_csv()))
# Out:
#                                                         Description  \
# IntraGroupingKey
# 839bd                                              WILL PENN TAVERN
# fed3c                              MESSED UP SOME MATH WILL PENN PT
# 28855                                           RAJ S FRIDAY DINNER
# c685a                                                         LUNCH
# 9075a             BKOFAMERICA ATM WITHDRWL LAGUARDIA AIRPORT LAG...
# ...                                                             ...
# 52bc0             REQUESTED TRANSFER TO LEN G HUANG BANK OF AMER...
# 52b46                                        SEAMLSS MEILAIWAHBAKER
# 5295a                                              TST LOS TACOS NO
# 52614                                                   TRADER JOES
# ffbd6                            TST CHEF PAPA LONG LONG ISLAND CNY
#
#                   FirstDate   LastDate  DuplicateCount    Amount  \
# IntraGroupingKey
# 839bd             4/14/2024  4/14/2024               8       $26
# fed3c             4/14/2024  4/14/2024               8     $1.46
# 28855             4/21/2024  4/21/2024               8    $21.71
# c685a             2/19/2024  2/19/2024               6       $20
# 9075a             1/21/2025  1/21/2025               6    ($300)
# ...                     ...        ...             ...       ...
# 52bc0             1/29/2024  1/29/2024               2   ($2120)
# 52b46             11/9/2024  11/9/2024               2  ($43.03)
# 5295a             5/15/2024  5/15/2024               2   ($15.7)
# 52614              1/6/2024   1/6/2024               2  ($35.72)
# ffbd6             11/1/2024  11/1/2024               2  ($43.14)
#
#                                                         SourceFiles
# IntraGroupingKey
# 839bd             transactions_dummy_to_test_duplicates.csv, tra...
# fed3c             transactions_dummy_to_test_duplicates.csv, tra...
# 28855             transactions_dummy_to_test_duplicates.csv, tra...
# c685a             transactions_dummy_to_test_duplicates.csv, tra...
# 9075a             transactions_dummy_to_test_duplicates.csv, tra...
# ...                                                             ...
# 52bc0             transactions_dummy_to_test_duplicates.csv, tra...
# 52b46             transactions_dummy_to_test_duplicates.csv, tra...
# 5295a             transactions_dummy_to_test_duplicates.csv, tra...
# 52614             transactions_dummy_to_test_duplicates.csv, tra...
# ffbd6             transactions_dummy_to_test_duplicates.csv, tra...
#
# [1946 rows x 6 columns]

# %% [markdown]
# How might we solve duplicate within a file though? Many of these are Venmo statements that some of the naming/description gets cut out from the description. Namely, should we add better descriptions before passing in the data? I think it'll be ok to coalesce all the `Intra` duplicates and then filter out any `Inter` duplicates AFTER coalescing all the `Intra` ones.

# %% [markdown]
# ## Reformatting the Data
#
# Here, we want to convert some of the values to things that will be easier to work with.
# When reading it in, everything is a string. We want:
# - the string `Date` to be datetime objects
# - `Is Hidden` / `Is Pending` to bools
# - `Amount` to be positive/negative numbers rather than accounting style strings.

# %%
def convert_types(df):
    # Convert dates to date times
    df['Date'] = pd.to_datetime(df['Date'])

    # Convert strings to bools
    df['Is Hidden'] = df['Is Hidden'].replace({'yes': True, 'no': False})
    df['Is Pending'] = df['Is Pending'].replace({'yes': True, 'no': False})

    # Remove $ and whitespace, remove parantheses from numbers, then convert to float
    df['Amount'] = df['Amount'].replace(r'[$\s]', '', regex=True).replace(r'\(([\d.]+)\)', r'-\1', regex=True).astype(float)

    return df

convert_types(add_row_hashes(read_transaction_csv()))
# Out:
#                      Date                                        Description  \
# InterRowHashID
# 4d236_1        2025-06-11     ALLY BANK DES TRANSFER INDN LEN G HUANG CO WEB
# 381b5_1        2025-06-11            VENMO DES PAYMENT INDN LEN HUANG CO WEB
# 8e2b1_1        2025-06-11  ALLY BANK DES ID LEN G HUANG INDN LEN G HUANG ...
# 5e116_1        2025-06-10                             OZZIES FRESH MARKET NY
# 30ac5_1        2025-06-10                         SECURITY DEPOSIT UNION AVE
# ...                   ...                                                ...
# a7b69_1        2024-01-02      ONLINE BANKING TRANSFER FROM CHK CONFIRMATION
# 05463_1        2024-01-01                                 COURT SQUARE DINER
# 2cf10_1        2024-01-01                                     NJT RAIL MYTIX
# ff421_1        2024-01-01                                             TARGET
# 01228_1        2024-01-01                              ANNUAL MEMBERSHIP FEE
#
#                                          Institution  \
# InterRowHashID
# 4d236_1         Bank of America - via Direct Web API
# 381b5_1         Bank of America - via Direct Web API
# 8e2b1_1         Bank of America - via Direct Web API
# 5e116_1         Bank of America - via Direct Web API
# 30ac5_1                Venmo - via Direct Web Access
# ...                                              ...
# a7b69_1         Bank of America - via Direct Web API
# 05463_1                                        Chase
# 2cf10_1                                        Chase
# ff421_1                                        Chase
# 01228_1                                        Chase
#
#                                                       Account  \
# InterRowHashID
# 4d236_1                               Adv Plus Banking - 2082
# 381b5_1                               Adv Plus Banking - 2082
# 8e2b1_1                               Adv Plus Banking - 2082
# 5e116_1         Customized Cash Rewards Visa Signature - 0966
# 30ac5_1                                                 Venmo
# ...                                                       ...
# a7b69_1                               Adv Plus Banking - 2082
# 05463_1                                        Other Spending
# 2cf10_1                                        Other Spending
# ff421_1                                        Other Spending
# 01228_1                                           Travel Card
#
#                           Category Is Hidden Is Pending   Amount  \
# InterRowHashID
# 4d236_1                  Transfers        No         No  -400.00
# 381b5_1             Online Payment        No         No -2500.00
# 8e2b1_1                     Income        No         No  5000.00
# 5e116_1                  Groceries        No         No    -6.99
# 30ac5_1                     Income        No         No -2500.00
# ...                            ...       ...        ...      ...
# a7b69_1                  Transfers        No         No   300.00
# 05463_1         Restaurants/Dining        No         No   -77.65
# 2cf10_1           Public Transport        No         No    -8.50
# ff421_1                   Shopping        No         No   -14.34
# 01228_1             Fees & Charges        No         No   -95.00
#
#                                                SourceFile IntraGroupingKey  \
# InterRowHashID
# 4d236_1         transactions_dummy_to_test_duplicates.csv            e3637
# 381b5_1         transactions_dummy_to_test_duplicates.csv            94c5e
# 8e2b1_1         transactions_dummy_to_test_duplicates.csv            72b02
# 5e116_1         transactions_dummy_to_test_duplicates.csv            4871c
# 30ac5_1         transactions_dummy_to_test_duplicates.csv            a1c2b
# ...                                                   ...              ...
# a7b69_1                       transactions_2025_06_13.csv            2d51e
# 05463_1                       transactions_2025_06_13.csv            92d6d
# 2cf10_1                       transactions_2025_06_13.csv            ee82d
# ff421_1                       transactions_2025_06_13.csv            f370a
# 01228_1                       transactions_2025_06_13.csv            7df83
#
#                InterGroupingKey IntraRowHashID
# InterRowHashID
# 4d236_1                   4d236        e3637_1
# 381b5_1                   381b5        94c5e_1
# 8e2b1_1                   8e2b1        72b02_1
# 5e116_1                   5e116        4871c_1
# 30ac5_1                   30ac5        a1c2b_1
# ...                         ...            ...
# a7b69_1                   a7b69        2d51e_2
# 05463_1                   05463        92d6d_2
# 2cf10_1                   2cf10        ee82d_2
# ff421_1                   ff421        f370a_2
# 01228_1                   01228        7df83_2
#
# [3976 rows x 12 columns]

# %% [markdown]
# # Coalescing Duplicates
#
# Below, we seek to take any duplicates from `IntraGroupingKey` and consolidate them into one value with the sum of the amounts.

# %%
def coalesce_duplicates(df, key='IntraGroupingKey'):
    if key not in df.columns:
        raise KeyError(f"{key!r} column not found. Columns: {df.columns.tolist()}")
    if df[key].isna().all():
        raise ValueError(f"All values in {key!r} are NaN/blank.")

    amount_cols = df.select_dtypes('number').columns.difference([key])
    other_cols  = df.columns.difference(amount_cols.union([key]))

    return (
        df.groupby(key, as_index=False, dropna=False)
          .agg({**{c: 'sum' for c in amount_cols},
                **{c: 'first' for c in other_cols}})
    )

coalesce_duplicates(convert_types(add_row_hashes(read_transaction_csv())))
# Out:
#      IntraGroupingKey  Amount                              Account  \
# 0               00016  -10.86                       Other Spending
# 1               004af   36.66                                Venmo
# 2               005a2 -800.00              Adv Plus Banking - 2082
# 3               00725  -49.48                          CREDIT CARD
# 4               0083a -375.64                       Other Spending
# ...               ...     ...                                  ...
# 1941            fed3c   11.68                                Venmo
# 1942            ff7de  184.96                                Venmo
# 1943            ff972   58.40                 Ally Savings Account
# 1944            ffa5a  147.70                                Venmo
# 1945            ffbd6  -86.28  BILT WORLD ELITE MASTERCARD ...7685
#
#                      Category       Date  \
# 0     Fast Food & Convenience 2025-01-03
# 1                   Rideshare 2025-01-24
# 2                   Transfers 2024-05-01
# 3                   Groceries 2024-03-11
# 4         Credit Card Payment 2024-11-03
# ...                       ...        ...
# 1941                   Income 2024-04-14
# 1942                   Income 2025-05-07
# 1943          Interest Income 2025-06-08
# 1944                   Income 2024-02-05
# 1945       Restaurants/Dining 2024-11-01
#
#                                             Description  \
# 0                                    TOO GOOD TO GO INC
# 1     AIRPORT TAXI S THERE BACK JUST ONE WAY FOR SACHIT
# 2        ALLY BANK DES TRANSFER INDN LEN G HUANG CO WEB
# 3                                           TRADER JOES
# 4                                FSI CONED BILL PAYMENT
# ...                                                 ...
# 1941                   MESSED UP SOME MATH WILL PENN PT
# 1942                                         MAY CRUNCH
# 1943                                      INTEREST PAID
# 1944                                         PICKLEBACK
# 1945                 TST CHEF PAPA LONG LONG ISLAND CNY
#
#                                           Institution InterGroupingKey  \
# 0                                               Chase            0b879
# 1                       Venmo - via Direct Web Access            77992
# 2                Bank of America - via Direct Web API            47e7b
# 3                                               Chase            09e01
# 4                                               Chase            daaa9
# ...                                               ...              ...
# 1941                    Venmo - via Direct Web Access            886c8
# 1942                    Venmo - via Direct Web Access            41f3e
# 1943                                             Ally            f5055
# 1944                    Venmo - via Direct Web Access            fdd43
# 1945  Wells Fargo Online Banking - via Direct Web API            60341
#
#      IntraRowHashID Is Hidden Is Pending  \
# 0           00016_1        No         No
# 1           004af_1        No         No
# 2           005a2_1        No         No
# 3           00725_1        No         No
# 4           0083a_1        No         No
# ...             ...       ...        ...
# 1941        fed3c_1        No         No
# 1942        ff7de_1        No         No
# 1943        ff972_1        No         No
# 1944        ffa5a_1        No         No
# 1945        ffbd6_1        No         No
#
#                                      SourceFile
# 0     transactions_dummy_to_test_duplicates.csv
# 1     transactions_dummy_to_test_duplicates.csv
# 2     transactions_dummy_to_test_duplicates.csv
# 3     transactions_dummy_to_test_duplicates.csv
# 4     transactions_dummy_to_test_duplicates.csv
# ...                                         ...
# 1941  transactions_dummy_to_test_duplicates.csv
# 1942  transactions_dummy_to_test_duplicates.csv
# 1943  transactions_dummy_to_test_duplicates.csv
# 1944  transactions_dummy_to_test_duplicates.csv
# 1945  transactions_dummy_to_test_duplicates.csv
#
# [1946 rows x 12 columns]

# %% [markdown]
# We can now se that there's no duplicates in our data! At least, no INTRA duplicates. What about inter?

# %%
duplicates_summary(coalesce_duplicates(convert_types(add_row_hashes(read_transaction_csv())), key='IntraGroupingKey'), key='InterGroupingKey')
# Out:
# Empty DataFrame
# Columns: [Description, FirstDate, LastDate, DuplicateCount, Amount, SourceFiles]
# Index: []

# %%
duplicates_summary(coalesce_duplicates(convert_types(add_row_hashes(read_transaction_csv())), key='InterGroupingKey'), key='IntraGroupingKey')
# Out:
#                                                         Description  \
# IntraGroupingKey
# 00016                                            TOO GOOD TO GO INC
# a6eb7             SMALL BUT HOPE THIS HELPS WITH SOMETHING BOOTH...
# aaa61                                           SEP OCT ELECTRICITY
# aa877                                     FID BKG SVC LLC MONEYLINE
# aa4c0                                                     LYFT RIDE
# ...                                                             ...
# 52330                                              UBER HOME MIRAGE
# 522fe                                                   TRADER JOES
# 520a4                                              PIZZERIA SCIALLA
# 5208a                                                   TRADER JOES
# ffbd6                            TST CHEF PAPA LONG LONG ISLAND CNY
#
#                   FirstDate   LastDate  DuplicateCount  Amount  \
# IntraGroupingKey
# 00016            2025-01-03 2025-01-03               2   -5.43
# a6eb7            2025-04-02 2025-04-02               2 -100.00
# aaa61            2024-10-10 2024-10-10               2   64.85
# aa877            2024-07-02 2024-07-02               2 -700.00
# aa4c0            2024-04-16 2024-04-16               2  -49.03
# ...                     ...        ...             ...     ...
# 52330            2024-07-20 2024-07-20               2   -9.00
# 522fe            2024-09-15 2024-09-15               2  -48.71
# 520a4            2024-03-04 2024-03-04               2  -21.15
# 5208a            2024-03-18 2024-03-18               2   -2.99
# ffbd6            2024-11-01 2024-11-01               2  -43.14
#
#                                                         SourceFiles
# IntraGroupingKey
# 00016             transactions_dummy_to_test_duplicates.csv, tra...
# a6eb7             transactions_dummy_to_test_duplicates.csv, tra...
# aaa61             transactions_dummy_to_test_duplicates.csv, tra...
# aa877             transactions_dummy_to_test_duplicates.csv, tra...
# aa4c0             transactions_dummy_to_test_duplicates.csv, tra...
# ...                                                             ...
# 52330             transactions_dummy_to_test_duplicates.csv, tra...
# 522fe             transactions_dummy_to_test_duplicates.csv, tra...
# 520a4             transactions_dummy_to_test_duplicates.csv, tra...
# 5208a             transactions_dummy_to_test_duplicates.csv, tra...
# ffbd6             transactions_dummy_to_test_duplicates.csv, tra...
#
# [1942 rows x 6 columns]

# %% [markdown]
# We can see depending on how we use this, we have cleaned up some of the duplicates! Though I think as I'm writing this I may have confused my notion of Intra and Inter lol. Since Inter takes in the source name, it will group things within a file. Then I want to remove duplicates based on Intra. Let me see if I can get some Inter's to show up together.

# %%
def test_coalesce_duplicates():
    df = convert_types(add_row_hashes(read_transaction_csv()))
    df = coalesce_duplicates(df, key='InterGroupingKey')
    row1 = find_row_from_hash(df, hash='886c8') # IntraGroupKey hash
    row2 = find_row_from_hash(df, hash='fed3c') # InterGroupKey hash
    return row1, row2

test_coalesce_duplicates()
# Out:
# No rows match prefix '886c8'
# No rows match prefix 'fed3c'
# (Empty DataFrame
#  Columns: [InterGroupingKey, Amount, Account, Category, Date, Description, Institution, IntraGroupingKey, IntraRowHashID, Is Hidden, Is Pending, SourceFile]
#  Index: [],
#  Empty DataFrame
#  Columns: [InterGroupingKey, Amount, Account, Category, Date, Description, Institution, IntraGroupingKey, IntraRowHashID, Is Hidden, Is Pending, SourceFile]
#  Index: [])

# %% [markdown]
# Hmmm... something's not adding up
